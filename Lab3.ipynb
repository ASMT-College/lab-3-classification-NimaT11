# %% [markdown]
# **Lab-3: Classification**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# %%
data = {
    'Pregnancies': [6, 1, 8, 1, 0, 5, 3, 10, 2, 8],
    'Glucose': [148, 85, 183, 89, 137, 116, 78, 115, 197, 125],
    'BloodPressure': [72, 66, 64, 66, 40, 74, 50, 0, 70, 96],
    'SkinThickness': [35, 29, 0, 23, 35, 0, 32, 0, 45, 0],
    'Insulin': [0, 0, 0, 94, 168, 0, 88, 0, 543, 0],
    'BMI': [33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31.0, 35.3, 30.5, 30.0],
    'DiabetesPedigreeFunction': [0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158, 0.232],
    'Age': [50, 31, 32, 21, 33, 30, 26, 29, 53, 54],
    'Outcome': [1, 0, 1, 0, 1, 0, 0, 0, 1, 1]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0  30.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        0
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
# Splitting training and testing data
X = df.drop(columns='Outcome')
Y = df['Outcome']

# %% [markdown]
# **Splitting the data into training and testing sets**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
print(x_train,y_train)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 7           10      115              0              0        0  35.3
# 2            8      183             64              0        0  23.3
# 9            8      125             96              0        0  30.0
# 4            0      137             40             35      168  43.1
# 3            1       89             66             23       94  28.1
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 7                     0.134   29
# 2                     0.672   32
# 9                     0.232   54
# 4                     2.288   33
# 3                     0.167   21
# 6                     0.248   26   0    1
# 7    0
# 2    1
# 9    1
# 4    1
# 3    0
# 6    0
# Name: Outcome, dtype: int64

# %% [markdown]
# **Using Gaussian Classifier**

# %%
nb_classifier = GaussianNB()

# Training the model using gaussian navie bayes
nb_classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# **Making prediction using model**

# %%
y_pred_nb = nb_classifier.predict(x_test)
print(y_pred_nb)
# Out:
# [1 0 0]

# %% [markdown]
# **Determining the accuracy of model**

# %%
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print(f"\n Accuracy of Model: {accuracy_nb:.2f}")
# Out:
#  Accuracy of Model: 1.00

# %% [markdown]
# **Classification Report for the model**

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred_nb))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %% [markdown]
# **Classification using ID3**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# **Data to be classified**

# %%
data = {
    'Pregnancies': [6, 1, 8, 1, 0, 5, 3, 10, 2, 8],
    'Glucose': [148, 85, 183, 89, 137, 116, 78, 115, 197, 125],
    'BloodPressure': [72, 66, 64, 66, 40, 74, 50, 0, 70, 96],
    'SkinThickness': [35, 29, 0, 23, 35, 0, 32, 0, 45, 0],
    'Insulin': [0, 0, 0, 94, 168, 0, 88, 0, 543, 0],
    'BMI': [33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31.0, 35.3, 30.5, 30.0],
    'DiabetesPedigreeFunction': [0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158, 0.232],
    'Age': [50, 31, 32, 21, 33, 30, 26, 29, 53, 54],
    'Outcome': [1, 0, 1, 0, 1, 0, 0, 0, 1, 1]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0  30.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        0
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
# Splitting the attributes and class to predict
X = df.drop(columns='Outcome')
Y = data['Outcome']

# %% [markdown]
# **Splitting training and testing data for the model**

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y)
print(x_train,x_test)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 4            0      137             40             35      168  43.1
# 3            1       89             66             23       94  28.1
# 1            1       85             66             29        0  26.6
# 8            2      197             70             45      543  30.5
# 7           10      115              0              0        0  35.3
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 4                     2.288   33
# 3                     0.167   21
# 1                     0.351   31
# 8                     0.158   53
# 7                     0.134   29
# 2                     0.672   32      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 9            8      125             96              0        0  30.0
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age
# 9                     0.232   54
# 5                     0.201   30
# 6                     0.248   26

# %% [markdown]
# **Training the model**

# %%
dt_classifier = DecisionTreeClassifier(criterion='entropy', random_state=42)
dt_classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# **Model Prediction**

# %%
y_pred_dt = dt_classifier.predict(x_test)
print(y_pred_dt)
# Out:
# [1 0 0]

# %% [markdown]
# **Evaluating model accuracy**

# %%
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f"Decision Tree Accuracy: {accuracy_dt:.2f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 1.00
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
